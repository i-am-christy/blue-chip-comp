# %% [markdown]
# # Importing important libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading the data

# %%
#loading the data from the csv file
test_df = pd.read_csv("test.csv")
train_df = pd.read_csv("train.csv")

# %%
#reading the first five rows of the data
display(train_df.head())
#display(test_df.head())
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# ...

# %%
#getting info about the data
print(train_df.info())
#print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   int64
#  1   Age                       1677 non-null   int64
#  2   BusinessTravel            1677 non-null   object
#  3   DailyRate                 1677 non-null   int64
#  4   Department                1677 non-null   object
#  5   DistanceFromHome          1677 non-null   int64
#  6   Education                 1677 non-null   int64
#  7   EducationField            1677 non-null   object
#  8   EmployeeCount             1677 non-null   int64
#  9   EnvironmentSatisfaction   1677 non-null   int64
#  10  Gender                    1677 non-null   object
#  11  HourlyRate                1677 non-null   int64
#  12  JobInvolvement            1677 non-null   int64
#  13  JobLevel                  1677 non-null   int64
# ...

# %%
#check for missing or null values
train_df.isnull().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
#check for duplicates
print(train_df.duplicated(keep="first").sum())
# Out:
# 0

# %%
train_df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# id                        1677.0    838.000000   484.252517     0.0   419.0
# Age                       1677.0     36.036971     8.507112    18.0    30.0
# DailyRate                 1677.0    892.749553   374.496259   107.0   589.0
# DistanceFromHome          1677.0      8.683959     7.826143     1.0     2.0
# Education                 1677.0      2.937984     1.039078     1.0     2.0
# EmployeeCount             1677.0      1.000000     0.000000     1.0     1.0
# EnvironmentSatisfaction   1677.0      2.757901     1.086835     1.0     2.0
# HourlyRate                1677.0     67.798450    19.435928    30.0    51.0
# JobInvolvement            1677.0      2.782349     0.650664     1.0     2.0
# JobLevel                  1677.0      1.998807     1.083065     1.0     1.0
# JobSatisfaction           1677.0      2.791890     1.097396     1.0     2.0
# ...

# %%
#checking the shape of the dataset
train_df.shape
# Out:
# (1677, 35)

# %% [markdown]
# # Exploratory Data Analysis

# %%
#plotting the joblevel against the monthly income
sns.barplot(x = train_df["JobLevel"], y = train_df["MonthlyIncome"], hue=train_df["Attrition"])
plt.title("Monthly Income by Job level")
plt.xlabel("Job Level")
plt.ylabel("Monthly Income")
plt.show()
plt.tight_layout()

# %%
#visualizing the attrition column
attrition = train_df["Attrition"].value_counts().index.to_list()
attrition = ["Churned" if i == 1 else "Not Churned" for i in attrition]
plt.pie(x = train_df["Attrition"].value_counts(), labels= attrition, autopct= "%1.1f%%", explode= [0, 0.3])
plt.show()

# %%
#checking out the monthly income by department
sns.countplot(train_df,  x ="Department", hue="Attrition")
# Out:
# <AxesSubplot: xlabel='Department', ylabel='count'>

# %%
train_df.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
#visualizing the year at company with attrition
sns.lineplot(train_df,  x ="YearsAtCompany",y="MonthlyIncome")
# Out:
# <AxesSubplot: xlabel='YearsAtCompany', ylabel='MonthlyIncome'>

# %%
ax = sns.countplot(train_df,  y ="YearsAtCompany", hue="Attrition")
fig = plt.gcf()  
fig.set_size_inches(15, 25)

# %%
#visualizing education and monthly income
ax = sns.barplot(train_df, x="EducationField", y="MonthlyIncome", hue="Attrition")
fig = plt.gcf()  
fig.set_size_inches(15, 15)

# %%
#environmentsatisfaction and attrition
sns.countplot(train_df, x="EnvironmentSatisfaction", hue="Attrition")
# Out:
# <AxesSubplot: xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
#gender 
gender = train_df["Gender"].value_counts().to_list()
plt.pie(train_df["Gender"].value_counts(), autopct= "%1.1f%%", explode= [0, 0.1])
plt.legend(gender, loc="best")
plt.title("Employee count by Gender")
plt.show()

# %%
#gender and attrition
sns.countplot(train_df, x="Gender", hue="Attrition")
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='count'>

# %%
#distancefromhome and attrition
ax = sns.countplot(train_df, y="DistanceFromHome", hue="Attrition")
fig = plt.gcf()  
fig.set_size_inches(25, 15)

# %%
#visualizing info about the gender
ax = sns.barplot(train_df, x="JobRole", y="MonthlyIncome", hue="Gender")
fig = plt.gcf()  
fig.set_size_inches(10, 10)
ax.tick_params(axis='x', rotation=90)

# %%
#separating the explanatory and response variable
x_train = train_df.drop(['Attrition'], axis=1)
y_train = train_df["Attrition"]
x_train
#train_df.columns
# Out:
#         id  Age     BusinessTravel  DailyRate              Department  \
# 0        0   36  Travel_Frequently        599  Research & Development
# 1        1   35      Travel_Rarely        921                   Sales
# 2        2   32      Travel_Rarely        718                   Sales
# 3        3   38      Travel_Rarely       1488  Research & Development
# 4        4   50      Travel_Rarely       1017  Research & Development
# ...    ...  ...                ...        ...                     ...
# 1672  1672   30      Travel_Rarely        945                   Sales
# 1673  1673   32      Travel_Rarely       1303  Research & Development
# 1674  1674   29  Travel_Frequently       1184         Human Resources
# 1675  1675   36      Travel_Rarely        441                   Sales
# 1676  1676   36      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
#separating numeric and categorical columns for the train df
num_cols = x_train.select_dtypes(["int", "float"])
cat_cols = x_train.select_dtypes("object")

# %%
#separating the categorical data for the test df
test_num_cols = test_df.select_dtypes(["int", "float"])
test_cat_cols = test_df.select_dtypes("object")

# %%
#detecting and removing outliers in the num_cols dataset
def plot_boxplot(df):
    for feature in df.columns:
        df.boxplot(column=[feature])
        plt.grid=(False)
        plt.show()

plot_boxplot(num_cols)

# %%
'''def get_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    upper = Q3 + (1.5 * IQR)
    lower = Q1 - (1.5 * IQR)
    
    outlier = df.index[(df[col] < lower) | (df[col] > upper)]
    return outlier
        
#create an empty lsit to store the output indices from multiple columns

index_list = []

for col in num_cols.columns:
    index_list.extend(get_outliers(num_cols, col))

len(index_list)'''
# Out:
# 'def get_outliers(df, col):\n    Q1 = df[col].quantile(0.25)\n    Q3 = df[col].quantile(0.75)\n    IQR = Q3 - Q1\n    upper = Q3 + (1.5 * IQR)\n    lower = Q1 - (1.5 * IQR)\n    \n    outlier = df.index[(df[col] < lower) | (df[col] > upper)]\n    return outlier\n        \n#create an empty lsit to store the output indices from multiple columns\n\nindex_list = []\n\nfor col in num_cols.columns:\n    index_list.extend(get_outliers(num_cols, col))\n\nlen(index_list)'

# %% [markdown]
# # Categorical Encoding

# %%
#encoding the training data
encoded = pd.get_dummies(cat_cols, prefix="cat")

# %%
encoded
# Out:
#       cat_Non-Travel  cat_Travel_Frequently  cat_Travel_Rarely  \
# 0                  0                      1                  0
# 1                  0                      0                  1
# 2                  0                      0                  1
# 3                  0                      0                  1
# 4                  0                      0                  1
# ...              ...                    ...                ...
# 1672               0                      0                  1
# 1673               0                      0                  1
# 1674               0                      1                  0
# 1675               0                      0                  1
# 1676               0                      0                  1
#
#       cat_Human Resources  cat_Research & Development  cat_Sales  \
# 0                       0                           1          0
# 1                       0                           0          1
# ...

# %%
#encoding the test data
test_encoded = pd.get_dummies(test_cat_cols, prefix="cat")

# %%
#merging the encoded and the numeric data together fr the training adatframe
x_train = num_cols.join(encoded)
x_train.set_index("id", inplace=True)

# %%
#merging the encoded and the numeric data together fr the test dataframe
test_df = test_num_cols.join(test_encoded)
test_df.set_index("id", inplace=True)

# %%
test_df.head()
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# id
# 1677   19        992                 1          1              1
# 1678   45       1136                 4          4              1
# 1679   37        155                13          3              1
# 1680   32        688                 1          4              1
# 1681   29        464                 9          1              1
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# id
# 1677                        4          43               3         1
# 1678                        3          67               3         2
# 1679                        4          41               3         1
# 1680                        3          89               2         2
# 1681                        3          79               3         1
#
#       JobSatisfaction  ...  cat_Research Director  cat_Research Scientist  \
# id                     ...
# ...

# %%
x_train.head()
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# id
# 0    36        599                24          3              1
# 1    35        921                 8          3              1
# 2    32        718                26          3              1
# 3    38       1488                 2          3              1
# 4    50       1017                 5          4              1
#
#     EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# id
# 0                         4          42               3         1
# 1                         1          46               3         1
# 2                         3          80               3         2
# 3                         3          40               3         2
# 4                         2          37               3         5
#
#     JobSatisfaction  ...  cat_Research Director  cat_Research Scientist  \
# id                   ...
# 0                 4  ...                      0                       0
# ...

# %%
#duplicated = x_train.columns[x_train.columns.duplicated()]
x_train = x_train.T.groupby(level=0).first().T
x_train.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'cat_Divorced', 'cat_Female', 'cat_Healthcare Representative',
#        'cat_Human Resources', 'cat_Laboratory Technician', 'cat_Life Sciences',
#        'cat_Male', 'cat_Manager', 'cat_Manufacturing Director',
#        'cat_Marketing', 'cat_Married', 'cat_Medical', 'cat_No',
#        'cat_Non-Travel', 'cat_Other', 'cat_Research & Development',
#        'cat_Research Director', 'cat_Research Scientist', 'cat_Sales',
# ...

# %% [markdown]
# # Feature Scaling

# %%
#importing the robust scaler
from sklearn.preprocessing import RobustScaler

# %%
#initializing the scaler
robust_scaler = RobustScaler()

# %%
#sacling the data
x_train = robust_scaler.fit_transform(x_train)

# %%
#observing the scaled data
x_train.shape
# Out:
# (1677, 52)

# %% [markdown]
# # spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting the data into training and testsing data
x_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train)

# %% [markdown]
# # Model Training

# %%
#importing the model
from sklearn.ensemble import GradientBoostingClassifier

# %%
#instatiate the model
GBClassifier = GradientBoostingClassifier()

# %%
#fit our data
GBClassifier.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
#use the model to get a prediction
GB_ypred = GBClassifier.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
#importing evaluation library
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

#evaluating our model accuracy
accuracy_score(y_test, GB_ypred)
# Out:
# 0.8869047619047619

# %%
#plotting the confusion matrix
from sklearn.metrics import plot_confusion_matrix

# Get confusion matrix for Gradient Boosting Classifier
plot_confusion_matrix(GBClassifier, X_test, y_test, normalize='true')
# Out:
# C:\Users\Christianah\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#printing the classification report
print(classification_report(y_test, GB_ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       296
#            1       0.57      0.20      0.30        40
#
#     accuracy                           0.89       336
#    macro avg       0.74      0.59      0.62       336
# weighted avg       0.86      0.89      0.86       336

# %% [markdown]
# #logistic regression model

# %%
from sklearn.linear_model import LogisticRegression
#instantiate the model
logReg = LogisticRegression()

# %%
#fit the data
logReg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#make predictions
logReg_ypred = logReg.predict(X_test)

# %%
#evaluate the model
accuracy_score(y_test, logReg_ypred)
# Out:
# 0.8839285714285714

# %%
#printing the classification report
print(classification_report(y_test, logReg_ypred))

#visualizing the confusion matrix
confusion_matrix = confusion_matrix(y_test, logReg_ypred)
#plotting the confusion matrix usinh heatmap
sns.heatmap(confusion_matrix, annot=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       296
#            1       0.54      0.17      0.26        40
#
#     accuracy                           0.88       336
#    macro avg       0.72      0.58      0.60       336
# weighted avg       0.86      0.88      0.86       336

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#create an instance of the model
random = RandomForestClassifier(n_estimators=100)
#fit the model
random.fit(x_train, y_train)
#make predictions
random_ypred = random.predict(X_test)

# %%
#checking the accuracy of the model
accuracy_score(y_test, random_ypred)
# Out:
# 0.8839285714285714

# %%
#printing the classification report
print(classification_report(y_test, random_ypred))

'''#visualizing the condusion matrix
cm = confusion_matrix(y_test, random_ypred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm_normalized, annot=True)'''
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       296
#            1       0.67      0.05      0.09        40
#
#     accuracy                           0.88       336
#    macro avg       0.78      0.52      0.52       336
# weighted avg       0.86      0.88      0.84       336
# "#visualizing the condusion matrix\ncm = confusion_matrix(y_test, random_ypred)\ncm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]\nsns.heatmap(cm_normalized, annot=True)"

# %% [markdown]
# # XGBoost Classifier

# %%
#import classifier algorithm here
from xgboost import XGBClassifier

# create models
xg_model = XGBClassifier()

#fitting the models
xg_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
#getting predictions with the model
xg_ypred = xg_model.predict(X_test)

# %%
#evaluating the model
accuracy_score(y_test, xg_ypred)
# Out:
# 0.8869047619047619

# %%
# Get confusion matrix for Gradient Boosting Classifier
plot_confusion_matrix(xg_model, X_test, y_test, normalize='true')
# Out:
# C:\Users\Christianah\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#obtaining the classification report
print(classification_report(xg_ypred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94       320
#            1       0.23      0.56      0.32        16
#
#     accuracy                           0.89       336
#    macro avg       0.60      0.73      0.63       336
# weighted avg       0.94      0.89      0.91       336

# %% [markdown]
# # Hyperparameter Tunning

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV

# %%
#apecifying the hyperparameters in random forest to be tunned
parameters = {
    "criterion" : ["gini", "entropy"],
    "max_depth" : [1, 2, 4, 5, 10, 15],
    "min_samples_split" : [10, 20, 40, 50, 100, 150],
    "max_leaf_nodes" : [10, 15, 25, 50],
    "min_samples_leaf" : [100, 200, 300, 400, 500, 600],
    "n_estimators" : [0, 50, 100, 150, 200, 500],
    "max_samples" : [0, 0.1, 0.15, 0.2, 0.25, 0.3],
    "max_features" : [0, 1, 2, 3, 5, 7, "auto", "sqrt", "log2"]
}

# %%
#creating the kfold object
kfold = StratifiedKFold(n_splits=5)

# %%
#creating the grid search object
clf = GridSearchCV(random, parameters, scoring="accuracy", n_jobs=-1, cv=kfold)

# %%
#fit the gridsearch
clf.fit(x_train, y_train)

# %% [markdown]
# # getting the parameters used

# %%
clf.get_params_
